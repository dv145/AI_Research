# %%
import dill
dill.load_session('notebook_env.db')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator MLPRegressor from version 0.24.2 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
get_X_list(['Stephen Curry'], 2015)
# Out:
# [[27, 79, 30.1, 0.669, 0.629760951, 32.6, 6.7, 0, 40.76526726, 30.57395045]]

# %%
def get_X_2_list(names, season):
    
    stats = ['AGE','GP','PPG','TS%','eFG%','USG%','APG','AST%','PER_n','PER','VI','T_PTS','PACE','OEFF']
    
    A = get_X(names, season)
    

    X = []
        
    for i in range(len(A)):
    
        
        Player = []
    
        for stat in stats:
            
            try:
                
                if math.isnan(A[i][stat]):
            
                    Player.append(0)
                
                else:
                    Player.append((A[i][stat]))
                
            except:
                
                Player.append(0)
            
    
        X.append(Player)
        
    return X

# %%
get_X_list(['Stephen Curry'], 2015)
# Out:
# [[27,
#   79,
#   30.1,
#   0.669,
#   0.629760951,
#   32.6,
#   6.7,
#   0,
#   40.76526726,
#   30.57395045,
#   12.0,
#   0,
#   0,
#   0]]

# %%
X=get_X_list(names, 2019)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1000)
modod = MLPRegressor(hidden_layer_sizes = 150, random_state=1000, max_iter=500).fit(X_train, y_train)
modod.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xw/9p_kvdp557d5sy9x5jtrlchr0000gn/T/ipykernel_33413/4066762564.py in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1000)
#       2 modod = MLPRegressor(hidden_layer_sizes = 150, random_state=1000, max_iter=500).fit(X_train, y_train)
#       3 modod.score(X_test, y_test)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     291     """
# ...

# %%
X
# Out:
# [[27.07, 63.0, 10.9, 0.6, 0.59, 17.3, 2.3, 0, 21.9, 15.97, 9.2, 0, 0, 0],
#  [23.08, 72.0, 15.9, 0.6, 0.56, 21.2, 5.1, 0, 24.02, 17.51, 11.2, 0, 0, 0],
#  [35.07, 53.0, 18.9, 0.57, 0.53, 23.4, 2.4, 0, 23.08, 16.82, 8.4, 0, 0, 0],
#  [23.81, 2.0, 1.0, 0.5, 0.5, 9.9, 0.0, 0, -0.57, -0.42, 0.0, 0, 0, 0],
#  [21.95, 47.0, 5.7, 0.47, 0.46, 23.3, 1.9, 0, 11.59, 8.45, 8.5, 0, 0, 0],
#  [24.85, 38.0, 8.7, 0.61, 0.58, 17.6, 1.4, 0, 15.08, 10.99, 6.3, 0, 0, 0],
#  [22.32, 70.0, 11.1, 0.66, 0.65, 14.9, 1.6, 0, 23.61, 17.21, 8.4, 0, 0, 0],
#  [27.58, 10.0, 5.0, 0.51, 0.49, 20.6, 2.1, 0, 14.25, 10.39, 7.2, 0, 0, 0],
#  [29.9, 18.0, 4.3, 0.4, 0.34, 13.2, 1.2, 0, 8.96, 6.53, 5.6, 0, 0, 0],
#  [26.74, 10.0, 2.8, 0.35, 0.34, 17.1, 0.8, 0, 5.19, 3.78, 6.3, 0, 0, 0],
#  [26.9, 67.0, 5.8, 0.53, 0.51, 13.5, 2.4, 0, 15.3, 11.16, 7.9, 0, 0, 0],
#  [32.27, 2.0, 2.5, 0.36, 0.36, 23.7, 1.0, 0, 13.33, 9.71, 11.8, 0, 0, 0],
#  [25.69, 63.0, 29.5, 0.61, 0.59, 37.5, 5.6, 0, 41.12, 29.98, 17.2, 0, 0, 0],
# ...

# %%
y
# Out:
# [32.0, 25.0, 26.9, 24.8, 24.8, 28.1]

# %%
Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xw/9p_kvdp557d5sy9x5jtrlchr0000gn/T/ipykernel_33413/2821689564.py in <module>
# ----> 1 Y
#
# NameError: name 'Y' is not defined
